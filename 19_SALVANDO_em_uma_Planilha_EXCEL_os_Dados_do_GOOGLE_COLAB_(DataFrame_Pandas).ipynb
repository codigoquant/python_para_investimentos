# %% [markdown]
# <a href="https://colab.research.google.com/github/ricospeloacaso/python_para_investimentos/blob/master/19_SALVANDO_em_uma_Planilha_EXCEL_os_Dados_do_GOOGLE_COLAB_(DataFrame_Pandas).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Python para Investimentos

# %% [markdown]
# **Python para Investimentos** é um conjunto de códigos e vídeos em que mostro como utilizar a linguagem de programação PYTHON através da ferramenta online Google Colab para fazer estudos no mercado financeiro.

# %% [markdown]
# **Canal no Youtube:** https://www.youtube.com/ricospeloacaso?sub_confirmation=1

# %%
#@title Vídeo
from IPython.display import YouTubeVideo
YouTubeVideo('zekmnLPvqTM', width=854, height=480)

# %% [markdown]
# ###Bibliotecas

# %%
# !pip install yfinance

# %%
import yfinance as yf
import pandas as pd

# %%
from google.colab import files

# %% [markdown]
# ###Coletando Dados do site da B3

# %%
def busca_carteira_teorica(indice):
  url = 'http://bvmf.bmfbovespa.com.br/indices/ResumoCarteiraTeorica.aspx?Indice={}&idioma=pt-br'.format(indice.upper())
  return pd.read_html(url, decimal=',', thousands='.', index_col='Código')[0][:-1]

# %%
def get_tickers(indice):
  url = 'http://bvmf.bmfbovespa.com.br/indices/ResumoCarteiraTeorica.aspx?Indice={}&idioma=pt-br'.format(indice.upper())
  return (pd.read_html(url, decimal=',', thousands='.', index_col='Código')[0][:-1].index + '.SA').to_list()

# %% [markdown]
# ###Buscando os códigos das empresas que compõem os índices e baixando as cotações do Yahoo Finance

# %%
t = get_tickers('ibov')
t
# Out:
# ['ABEV3.SA',
#  'AZUL4.SA',
#  'B3SA3.SA',
#  'BBAS3.SA',
#  'BBDC3.SA',
#  'BBDC4.SA',
#  'BBSE3.SA',
#  'BEEF3.SA',
#  'BPAC11.SA',
#  'BRAP4.SA',
#  'BRDT3.SA',
#  'BRFS3.SA',
#  'BRKM5.SA',
#  'BRML3.SA',
#  'BTOW3.SA',
#  'CCRO3.SA',
#  'CIEL3.SA',
#  'CMIG4.SA',
#  'COGN3.SA',
#  'CPFE3.SA',
#  'CRFB3.SA',
#  'CSAN3.SA',
#  'CSNA3.SA',
#  'CVCB3.SA',
#  'CYRE3.SA',
#  'ECOR3.SA',
#  'EGIE3.SA',
#  'ELET3.SA',
#  'ELET6.SA',
#  'EMBR3.SA',
#  'ENBR3.SA',
#  'ENGI11.SA',
#  'EQTL3.SA',
#  'FLRY3.SA',
#  'GGBR4.SA',
#  'GNDI3.SA',
#  'GOAU4.SA',
#  'GOLL4.SA',
#  'HAPV3.SA',
#  'HGTX3.SA',
#  'HYPE3.SA',
#  'IGTA3.SA',
#  'IRBR3.SA',
#  'ITSA4.SA',
#  'ITUB4.SA',
#  'JBSS3.SA',
#  'KLBN11.SA',
#  'LAME4.SA',
#  'LREN3.SA',
#  'MGLU3.SA',
#  'MRFG3.SA',
#  'MRVE3.SA',
#  'MULT3.SA',
#  'NTCO3.SA',
#  'PCAR3.SA',
#  'PETR3.SA',
#  'PETR4.SA',
#  'QUAL3.SA',
#  'RADL3.SA',
#  'RAIL3.SA',
#  'RENT3.SA',
#  'SANB11.SA',
#  'SBSP3.SA',
#  'SULA11.SA',
#  'SUZB3.SA',
#  'TAEE11.SA',
# ...

# %%
ibov = yf.download(t, period='1mo', group_by='ticker')
ibov
# Out:
# [*********************100%***********************]  75 of 75 completed
#              EQTL3.SA                        ... GGBR4.SA
#                  Open       High        Low  ...    Close Adj Close    Volume
# Date                                         ...
# 2020-04-20  18.510000  19.580000  18.480000  ...    11.85     11.85  18250900
# 2020-04-22  19.299999  19.709999  19.010000  ...    11.70     11.70  16382600
# 2020-04-23  19.670000  19.950001  18.459999  ...    11.93     11.93  26135200
# 2020-04-24  18.350000  18.580000  16.850000  ...    10.93     10.93  30210500
# 2020-04-27  18.500000  19.180000  18.320000  ...    11.32     11.32  12234700
# 2020-04-28  19.500000  19.559999  18.770000  ...    11.98     11.98  21919700
# 2020-04-29  19.400000  19.400000  18.850000  ...    12.46     12.46  18142800
# 2020-04-30  18.780001  19.020000  18.010000  ...    11.74     11.74  15066900
# 2020-05-04  17.610001  18.270000  17.370001  ...    11.47     11.47  10749900
# ...

# %%
ifix = yf.download(get_tickers('ifix'), period='1mo', group_by='ticker')
ifix
# Out:
# [*********************100%***********************]  120 of 120 completed
#            IBFF11.SA                  ...  PORD11.SA
#                 Open High  Low Close  ...        Low      Close  Adj Close Volume
# Date                                  ...
# 2020-04-20       NaN  NaN  NaN   NaN  ...  93.120003  97.500000  97.500000    189
# 2020-04-22       NaN  NaN  NaN   NaN  ...  95.000000  97.800003  97.800003   1088
# 2020-04-23       NaN  NaN  NaN   NaN  ...  96.000000  98.699997  98.699997   1398
# 2020-04-24       NaN  NaN  NaN   NaN  ...  95.000000  97.720001  97.720001    668
# 2020-04-27       NaN  NaN  NaN   NaN  ...  97.050003  98.849998  98.849998    118
# 2020-04-28       NaN  NaN  NaN   NaN  ...  97.019997  98.599998  98.599998   1158
# 2020-04-29       NaN  NaN  NaN   NaN  ...  96.010002  97.000000  97.000000   1881
# 2020-04-30       NaN  NaN  NaN   NaN  ...  96.000000  97.790001  97.790001   2116
# ...

# %% [markdown]
# ###Salvando os Dados em uma Planilha Excel

# %%
ibov.to_excel('ibov.xlsx')
files.download('ibov.xlsx')

# %%
ifix.to_excel('ifix.xlsx')
files.download('ifix.xlsx')

# %% [markdown]
# ###Salvando os Dados em um Arquivo CSV

# %%
ibov.to_csv('ibov.csv')
files.download('ibov.csv')
